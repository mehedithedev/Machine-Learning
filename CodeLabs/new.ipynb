# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([1, 2, 3, 4, 5])
y = np.array([1, 4, 9, 16, 25])
# plt.subplot(1, 2, 1)

font1 = {'family':'sans','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}



# plt.pie(y)

plt.plot(x,y)
plt.scatter(x,y)
plt.bar(x,y, color='green')
# plt.hist(y)
plt.xlabel('Overs', fontdict=font1)
plt.ylabel('Runs', fontdict=font2)
plt.title('Cricket Match')
plt.grid()
plt.show()

# %%
x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %%
plt.pie(y)
# Out:
# ([<matplotlib.patches.Wedge at 0x107d2c2c0>,
#   <matplotlib.patches.Wedge at 0x107c71130>,
#   <matplotlib.patches.Wedge at 0x107c43140>,
#   <matplotlib.patches.Wedge at 0x107c40ce0>,
#   <matplotlib.patches.Wedge at 0x107c42a80>],
#  [Text(1.0982060144323316, 0.06279768996272098, ''),
#   Text(1.0360288040150372, 0.3696543212937894, ''),
#   Text(0.5133340946743531, 0.9728762034528661, ''),
#   Text(-0.8899186347901606, 0.6465638587589141, ''),
#   Text(0.156546237535796, -1.088803598227608, '')])
